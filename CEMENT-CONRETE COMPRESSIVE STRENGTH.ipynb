# %%
dataa = read.csv("D:/Project/phu.csv")

# %%
print(colnames(dataa))
# Out:
# [1] "ï..Cement..kg.m3."
# [2] "Concrete.compressive.strength..MPa.."

# %%
colnames(dataa)[1] <- "CEMENT"
colnames(dataa)[2] <- "Concrete.compressive.strength"

# %%
pairs(dataa,col = "#6F8FAF",main = "CEMENT-CONRETE COMPRESSIVE STRENGTH")
# Out:
# plot without title
